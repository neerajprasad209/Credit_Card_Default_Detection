# %%
import pandas as pd
import pymongo

# %%
data = pd.read_csv("https://raw.githubusercontent.com/neerajprasad209/CreditCard_fraud_Detection/main/Dataset/UCI_Credit_Card.csv")
data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
client = pymongo.MongoClient("mongodb+srv://neerajprasad209:neerajprasad209@neerajprasad209.p3s6l5t.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
## Create Database and collection name
db_name = client["ML_project"]
coll_name = db_name["CreditCard_Fault"]

# %%
DBdata = data.to_dict(orient='records')

# %%
DBdata
# Out:
# [{'ID': 1,
#   'LIMIT_BAL': 20000.0,
#   'SEX': 2,
#   'EDUCATION': 2,
#   'MARRIAGE': 1,
#   'AGE': 24,
#   'PAY_0': 2,
#   'PAY_2': 2,
#   'PAY_3': -1,
#   'PAY_4': -1,
#   'PAY_5': -2,
#   'PAY_6': -2,
#   'BILL_AMT1': 3913.0,
#   'BILL_AMT2': 3102.0,
#   'BILL_AMT3': 689.0,
#   'BILL_AMT4': 0.0,
#   'BILL_AMT5': 0.0,
#   'BILL_AMT6': 0.0,
#   'PAY_AMT1': 0.0,
#   'PAY_AMT2': 689.0,
#   'PAY_AMT3': 0.0,
#   'PAY_AMT4': 0.0,
#   'PAY_AMT5': 0.0,
#   'PAY_AMT6': 0.0,
#   'default.payment.next.month': 1},
#  {'ID': 2,
#   'LIMIT_BAL': 120000.0,
#   'SEX': 2,
#   'EDUCATION': 2,
#   'MARRIAGE': 2,
#   'AGE': 26,
#   'PAY_0': -1,
#   'PAY_2': 2,
#   'PAY_3': 0,
#   'PAY_4': 0,
#   'PAY_5': 0,
#   'PAY_6': 2,
#   'BILL_AMT1': 2682.0,
#   'BILL_AMT2': 1725.0,
#   'BILL_AMT3': 2682.0,
#   'BILL_AMT4': 3272.0,
#   'BILL_AMT5': 3455.0,
#   'BILL_AMT6': 3261.0,
#   'PAY_AMT1': 0.0,
#   'PAY_AMT2': 1000.0,
#   'PAY_AMT3': 1000.0,
#   'PAY_AMT4': 1000.0,
#   'PAY_AMT5': 0.0,
# ...

# %%
coll_name.insert_many(DBdata)
# Out:
# InsertManyResult([ObjectId('660d4057a99d230c0d638dbd'), ObjectId('660d4057a99d230c0d638dbe'), ObjectId('660d4057a99d230c0d638dbf'), ObjectId('660d4057a99d230c0d638dc0'), ObjectId('660d4057a99d230c0d638dc1'), ObjectId('660d4057a99d230c0d638dc2'), ObjectId('660d4057a99d230c0d638dc3'), ObjectId('660d4057a99d230c0d638dc4'), ObjectId('660d4057a99d230c0d638dc5'), ObjectId('660d4057a99d230c0d638dc6'), ObjectId('660d4057a99d230c0d638dc7'), ObjectId('660d4057a99d230c0d638dc8'), ObjectId('660d4057a99d230c0d638dc9'), ObjectId('660d4057a99d230c0d638dca'), ObjectId('660d4057a99d230c0d638dcb'), ObjectId('660d4057a99d230c0d638dcc'), ObjectId('660d4057a99d230c0d638dcd'), ObjectId('660d4057a99d230c0d638dce'), ObjectId('660d4057a99d230c0d638dcf'), ObjectId('660d4057a99d230c0d638dd0'), ObjectId('660d4057a99d230c0d638dd1'), ObjectId('660d4057a99d230c0d638dd2'), ObjectId('660d4057a99d230c0d638dd3'), ObjectId('660d4057a99d230c0d638dd4'), ObjectId('660d4057a99d230c0d638dd5'), ObjectId('660d4057a99d230c0d63
# ...
